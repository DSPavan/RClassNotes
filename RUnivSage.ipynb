# %%
#  stringsAsFactors = FALSE,
data2 <- read.csv("C:\\Users\\hp\\Downloads\\cerealspga05.csv", header = TRUE,
                 stringsAsFactors = FALSE,
                 strip.white = TRUE ,
                 sep = ',')

print(str(data2))
# Out:
# 'data.frame':	74 obs. of  16 variables:
#  $ name    : chr  "100%_Bran" "All-Bran" "All-Bran_with_Extra_Fiber" "Cracklin'_Oat_Bran" ...
#  $ mfr     : chr  "N" "K" "K" "K" ...
#  $ type    : chr  "C" "C" "C" "C" ...
#  $ calories: int  70 70 50 110 120 120 120 110 110 110 ...
#  $ protein : int  4 4 4 3 3 3 3 2 2 2 ...
#  $ fat     : int  1 1 0 3 1 1 5 2 2 0 ...
#  $ sodium  : int  130 260 140 140 200 210 15 200 180 125 ...
#  $ fiber   : num  10 9 14 4 6 5 2 1 1.5 1 ...
#  $ carbo   : num  5 7 8 10 11 14 8 14 10.5 11 ...
#  $ sugars  : int  6 5 0 7 14 12 8 8 10 14 ...
#  $ potass  : int  280 320 330 160 260 240 135 -1 70 30 ...
#  $ vitamins: int  25 25 25 25 25 25 0 25 25 25 ...
#  $ shelf   : int  3 3 3 3 3 2 3 3 1 2 ...
#  $ weight  : num  1 1 1 1 1.33 1.33 1 1 1 1 ...
#  $ cups    : num  0.33 0.33 0.5 0.5 0.67 0.75 1 0.75 0.75 1 ...
#  $ rating  : num  68.4 59.4 93.7 40.4 37.8 ...
# NULL

# %%
summary(data2)
# Out:
#      name               mfr                type              calories
#  Length:74          Length:74          Length:74          Min.   : 50.0
#  Class :character   Class :character   Class :character   1st Qu.:100.0
#  Mode  :character   Mode  :character   Mode  :character   Median :110.0
#                                                           Mean   :105.5
#                                                           3rd Qu.:110.0
#                                                           Max.   :160.0
#     protein         fat             sodium          fiber
#  Min.   :1.0   Min.   :0.0000   Min.   :  0.0   Min.   : 0.000
#  1st Qu.:2.0   1st Qu.:0.0000   1st Qu.:131.2   1st Qu.: 0.250
#  Median :2.0   Median :1.0000   Median :180.0   Median : 1.500
#  Mean   :2.5   Mean   :0.9459   Mean   :160.7   Mean   : 2.091
#  3rd Qu.:3.0   3rd Qu.:1.0000   3rd Qu.:217.5   3rd Qu.: 3.000
#  Max.   :6.0   Max.   :5.0000   Max.   :320.0   Max.   :14.000
# ...

# %%
summary(data2$sugars)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   -1.00    3.00    6.00    6.77   10.75   15.00

# %%
summary(data2$calories)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    50.0   100.0   110.0   105.5   110.0   160.0

# %%
# 1sr - 3 qt
# 100 - 110


# 3 - 11 sugars

# %%
library(psych)

describe(data2$sugars)

summary(data2$sugars)
# Out:
#    vars n  mean    sd       median trimmed  mad    min max range skew
# X1 1    74 6.77027 4.467684 6      6.733333 4.4478 -1  15  16    0.1097302
#    kurtosis  se
# X1 -1.172165 0.5193577
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   -1.00    3.00    6.00    6.77   10.75   15.00

# %%
# SD , SKEW, Kurtosis

# %%
library(pastecs)
stat.desc(data2$sugars)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
#   74.0000000    7.0000000    0.0000000   -1.0000000   15.0000000   16.0000000
#          sum       median         mean      SE.mean CI.mean.0.95          var
#  501.0000000    6.0000000    6.7702703    0.5193577    1.0350784   19.9601999
#      std.dev     coef.var
#    4.4676840    0.6598974

# %%
# var = SD ^2

# coef.var

# %%
hist(data2$calories,
     main = "Histogram of cal",
     xlab = "cal")
# Out:
# Plot with title "Histogram of cal"

# %%
# Create the histogram.
hist(data2$calories,
     xlab = "Sugar",
     col = "green",
     border = "red", 
     xlim = c(40,160),
     ylim = c(0,30),
   breaks = 10)
# Out:
# Plot with title "Histogram of data2$calories"

# %%
boxplot(data2$calories,
        main = toupper("Boxplot of Sugar"),
        ylab = "Frequency",
        col = "green")
# Out:
# Plot with title "BOXPLOT OF SUGAR"

# %%
d <- density(data2$calories, na.rm=TRUE)

plot(d, main = "Kernel density of Sugars")

polygon(d, col = "green", border = "blue")
# Out:
# Plot with title "Kernel density of Sugars"
