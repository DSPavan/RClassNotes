# %%
library(ggmap)
library(tidyverse)

api_key <- "AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw"
# Out:
# Loading required package: ggplot2
# Warning message:
# "package 'ggplot2' was built under R version 3.5.3"Google Maps API Terms of Service: http://developers.google.com/maps/terms.
# Please cite ggmap if you use it: see citation("ggmap") for details.
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v tibble  2.1.3     v purrr   0.2.5
# v tidyr   0.8.1     v dplyr   0.8.3
# v readr   1.1.1     v stringr 1.3.1
# v tibble  2.1.3     v forcats 0.3.0
# Warning message:
# "package 'tibble' was built under R version 3.5.3"Warning message:
# "package 'dplyr' was built under R version 3.5.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
register_google(key = api_key)
ggmap_credentials()
# Out:
# Google -
#    key : AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
#    account_type : standard
#    day_limit : 2500
#    second_limit : 50
#    client :
#    signature :

# %%
map2 <- get_map(
  location = c(lon = -74.0850869  , lat = 40.6454199),
    # 40.6454199,-74.0850869,1
    # lon = -94.9799357  , lat = 29.4027637
  #location = "Australia",
  zoom = 13,
  scale = 2,
  maptype = c(
    
    "roadmap"
    
  ),
  source = c("google"),
  api_key
)

ggmap(map2)
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=40.64542,-74.085087&zoom=13&size=640x640&scale=2&maptype=roadmap&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# plot without title

# %%
from <- c("houston, texas", "dallas")
to <- "waco, texas"
mapdist(from, to)
# Out:
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=dallas&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=houston%2C%20texas&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
#   from           to          m      km      miles     seconds minutes
# 1 houston, texas waco, texas 297356 297.356 184.77702 10293   171.55000
# 2 dallas         waco, texas 152482 152.482  94.75231  5410    90.16667
#   hours
# 1 2.859167
# 2 1.502778

# %%
from <- c("brooklyn, new york","new york" )
to <- "waco, texas"
mapdist(from, to)
# Out:
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=brooklyn%2C%20new%20york&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=new%20york&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
#   from               to          m       km       miles    seconds minutes
# 1 brooklyn, new york waco, texas 2658411 2658.411 1651.937 89234   1487.233
# 2 new york           waco, texas 2642709 2642.709 1642.179 88302   1471.700
#   hours
# 1 24.78722
# 2 24.52833

# %%
mapdist(from, to, mode = "driving")
mapdist(from, to, mode = "bicycling")
# Out:
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=brooklyn%2C%20new%20york&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=new%20york&destinations=waco%2C%20texas&mode=driving&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
#   from               to          m       km       miles    seconds minutes
# 1 brooklyn, new york waco, texas 2658411 2658.411 1651.937 89234   1487.233
# 2 new york           waco, texas 2642709 2642.709 1642.179 88302   1471.700
#   hours
# 1 24.78722
# 2 24.52833
# Source : https://maps.googleapis.com/maps/api/distancematrix/json?origins=brooklyn%2C%20new%20york&destinations=waco%2C%20texas&mode=bicycling&language=en-EN&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# ...

# %%
(wh <- as.numeric(geocode("brooklyn, new york")))
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=brooklyn%2C%20new%20york&key=AIzaSyClJVqN08I1oNYLYRw0mh_HCHP9rYoPZCw
# [1] -73.94416  40.67818
